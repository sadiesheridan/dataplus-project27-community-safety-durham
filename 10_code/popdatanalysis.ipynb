# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

popdata = gpd.read_file('/Users/erikrobertsson/Desktop/acs2020_5yr_B01003_15000US370630018091/acs2020_5yr_B01003_15000US370630018091.shp')
popdata.drop('B01003001e', axis=1, inplace=True)

print(popdata.shape) 
popdata.head(10)
# Out:
# (248, 4)
#                  geoid                       name  B01003001  \
# 0  15000US370630001011  Block Group 1, Durham, NC     1240.0
# 1  15000US370630001012  Block Group 2, Durham, NC     2476.0
# 2  15000US370630001021  Block Group 1, Durham, NC     1742.0
# 3  15000US370630001022  Block Group 2, Durham, NC      660.0
# 4  15000US370630001023  Block Group 3, Durham, NC      644.0
# 5  15000US370630001024  Block Group 4, Durham, NC      656.0
# 6  15000US370630002001  Block Group 1, Durham, NC     1086.0
# 7  15000US370630002002  Block Group 2, Durham, NC     1295.0
# 8  15000US370630002003  Block Group 3, Durham, NC      928.0
# 9  15000US370630003011  Block Group 1, Durham, NC     1290.0
#
#                                             geometry
# 0  POLYGON ((-78.89489 36.02991, -78.89343 36.030...
# 1  POLYGON ((-78.89232 36.03489, -78.89154 36.035...
# 2  POLYGON ((-78.91655 36.02532, -78.91635 36.025...
# 3  POLYGON ((-78.90229 36.02877, -78.90197 36.028...
# ...

# %%
popdata.plot(column='name', 
                         categorical=True, 
                         legend=True, 
                         figsize=(10,6),
                         markersize=0.05, 
                         cmap="Set2", aspect=1);
